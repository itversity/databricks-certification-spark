# %%
# %fs ls /public/retail_db
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/public/retail_db/categories/</td><td>categories/</td><td>0</td></tr><tr><td>dbfs:/public/retail_db/customers/</td><td>customers/</td><td>0</td></tr><tr><td>dbfs:/public/retail_db/departments/</td><td>departments/</td><td>0</td></tr><tr><td>dbfs:/public/retail_db/order_items/</td><td>order_items/</td><td>0</td></tr><tr><td>dbfs:/public/retail_db/orders/</td><td>orders/</td><td>0</td></tr><tr><td>dbfs:/public/retail_db/products/</td><td>products/</td><td>0</td></tr></tbody></table></div>

# %%
# %fs ls /public/retail_db/orders
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/public/retail_db/orders/part-00000</td><td>part-00000</td><td>2999944</td></tr></tbody></table></div>

# %%
orders = spark. \
    read. \
    csv('/public/retail_db/orders', inferSchema=True). \
    toDF('order_id', 'order_date', 'order_customer_id', 'order_status')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
orders.inputFiles()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: [&#39;dbfs:/public/retail_db/orders/part-00000&#39;]</div>

# %%
orders.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: [(&#39;order_id&#39;, &#39;int&#39;),
#  (&#39;order_date&#39;, &#39;string&#39;),
#  (&#39;order_customer_id&#39;, &#39;int&#39;),
#  (&#39;order_status&#39;, &#39;string&#39;)]</div>

# %%
orders.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+--------------------+-----------------+---------------+
# order_id|          order_date|order_customer_id|   order_status|
# +--------+--------------------+-----------------+---------------+
#        1|2013-07-25 00:00:...|            11599|         CLOSED|
#        2|2013-07-25 00:00:...|              256|PENDING_PAYMENT|
#        3|2013-07-25 00:00:...|            12111|       COMPLETE|
#        4|2013-07-25 00:00:...|             8827|         CLOSED|
#        5|2013-07-25 00:00:...|            11318|       COMPLETE|
#        6|2013-07-25 00:00:...|             7130|       COMPLETE|
#        7|2013-07-25 00:00:...|             4530|       COMPLETE|
#        8|2013-07-25 00:00:...|             2911|     PROCESSING|
#        9|2013-07-25 00:00:...|             5657|PENDING_PAYMENT|
#       10|2013-07-25 00:00:...|             5648|PENDING_PAYMENT|
#       11|2013-07-25 00:00:...|              918| PAYMENT_REVIEW|
#       12|2013-07-25 00:00:...|             1837|         CLOSED|
#       13|2013-07-25 00:00:...|             9149|PENDING_PAYMENT|
#       14|2013-07-25 00:00:...|             9842|     PROCESSING|
#       15|2013-07-25 00:00:...|             2568|       COMPLETE|
#       16|2013-07-25 00:00:...|             7276|PENDING_PAYMENT|
#       17|2013-07-25 00:00:...|             2667|       COMPLETE|
#       18|2013-07-25 00:00:...|             1205|         CLOSED|
#       19|2013-07-25 00:00:...|             9488|PENDING_PAYMENT|
#       20|2013-07-25 00:00:...|             9198|     PROCESSING|
# +--------+--------------------+-----------------+---------------+
# only showing top 20 rows
#
# </div>

# %%
# %fs ls /public/retail_db_json
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/public/retail_db_json/.git/</td><td>.git/</td><td>0</td></tr><tr><td>dbfs:/public/retail_db_json/categories/</td><td>categories/</td><td>0</td></tr><tr><td>dbfs:/public/retail_db_json/create_db_tables_pg.sql</td><td>create_db_tables_pg.sql</td><td>1748</td></tr><tr><td>dbfs:/public/retail_db_json/customers/</td><td>customers/</td><td>0</td></tr><tr><td>dbfs:/public/retail_db_json/departments/</td><td>departments/</td><td>0</td></tr><tr><td>dbfs:/public/retail_db_json/order_items/</td><td>order_items/</td><td>0</td></tr><tr><td>dbfs:/public/retail_db_json/orders/</td><td>orders/</td><td>0</td></tr><tr><td>dbfs:/public/retail_db_json/products/</td><td>products/</td><td>0</td></tr></tbody></table></div>

# %%
orders = spark.read.json('/public/retail_db_json/orders')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
orders.inputFiles()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: [&#39;dbfs:/public/retail_db_json/orders/part-r-00000-990f5773-9005-49ba-b670-631286032674&#39;]</div>

# %%
orders.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+--------------------+--------+---------------+
# order_customer_id|          order_date|order_id|   order_status|
# +-----------------+--------------------+--------+---------------+
#             11599|2013-07-25 00:00:...|       1|         CLOSED|
#               256|2013-07-25 00:00:...|       2|PENDING_PAYMENT|
#             12111|2013-07-25 00:00:...|       3|       COMPLETE|
#              8827|2013-07-25 00:00:...|       4|         CLOSED|
#             11318|2013-07-25 00:00:...|       5|       COMPLETE|
#              7130|2013-07-25 00:00:...|       6|       COMPLETE|
#              4530|2013-07-25 00:00:...|       7|       COMPLETE|
#              2911|2013-07-25 00:00:...|       8|     PROCESSING|
#              5657|2013-07-25 00:00:...|       9|PENDING_PAYMENT|
#              5648|2013-07-25 00:00:...|      10|PENDING_PAYMENT|
#               918|2013-07-25 00:00:...|      11| PAYMENT_REVIEW|
#              1837|2013-07-25 00:00:...|      12|         CLOSED|
#              9149|2013-07-25 00:00:...|      13|PENDING_PAYMENT|
#              9842|2013-07-25 00:00:...|      14|     PROCESSING|
#              2568|2013-07-25 00:00:...|      15|       COMPLETE|
#              7276|2013-07-25 00:00:...|      16|PENDING_PAYMENT|
#              2667|2013-07-25 00:00:...|      17|       COMPLETE|
#              1205|2013-07-25 00:00:...|      18|         CLOSED|
#              9488|2013-07-25 00:00:...|      19|PENDING_PAYMENT|
#              9198|2013-07-25 00:00:...|      20|     PROCESSING|
# +-----------------+--------------------+--------+---------------+
# only showing top 20 rows
#
# </div>

# %%
orders.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: [(&#39;order_customer_id&#39;, &#39;bigint&#39;),
#  (&#39;order_date&#39;, &#39;string&#39;),
#  (&#39;order_id&#39;, &#39;bigint&#39;),
#  (&#39;order_status&#39;, &#39;string&#39;)]</div>

# %%
order_items = spark.read.json('/public/retail_db_json/order_items')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
order_items.inputFiles()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: [&#39;dbfs:/public/retail_db_json/order_items/part-r-00000-6b83977e-3f20-404b-9b5f-29376ab1419e&#39;]</div>

# %%
order_items.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+-------------------+---------------------+------------------------+-------------------+-------------------+
# order_item_id|order_item_order_id|order_item_product_id|order_item_product_price|order_item_quantity|order_item_subtotal|
# +-------------+-------------------+---------------------+------------------------+-------------------+-------------------+
#             1|                  1|                  957|                  299.98|                  1|             299.98|
#             2|                  2|                 1073|                  199.99|                  1|             199.99|
#             3|                  2|                  502|                    50.0|                  5|              250.0|
#             4|                  2|                  403|                  129.99|                  1|             129.99|
#             5|                  4|                  897|                   24.99|                  2|              49.98|
#             6|                  4|                  365|                   59.99|                  5|             299.95|
#             7|                  4|                  502|                    50.0|                  3|              150.0|
#             8|                  4|                 1014|                   49.98|                  4|             199.92|
#             9|                  5|                  957|                  299.98|                  1|             299.98|
#            10|                  5|                  365|                   59.99|                  5|             299.95|
#            11|                  5|                 1014|                   49.98|                  2|              99.96|
#            12|                  5|                  957|                  299.98|                  1|             299.98|
#            13|                  5|                  403|                  129.99|                  1|             129.99|
#            14|                  7|                 1073|                  199.99|                  1|             199.99|
#            15|                  7|                  957|                  299.98|                  1|             299.98|
#            16|                  7|                  926|                   15.99|                  5|              79.95|
#            17|                  8|                  365|                   59.99|                  3|             179.97|
#            18|                  8|                  365|                   59.99|                  5|             299.95|
#            19|                  8|                 1014|                   49.98|                  4|             199.92|
#            20|                  8|                  502|                    50.0|                  1|               50.0|
# +-------------+-------------------+---------------------+------------------------+-------------------+-------------------+
# only showing top 20 rows
#
# </div>

# %%
order_items.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: [(&#39;order_item_id&#39;, &#39;bigint&#39;),
#  (&#39;order_item_order_id&#39;, &#39;bigint&#39;),
#  (&#39;order_item_product_id&#39;, &#39;bigint&#39;),
#  (&#39;order_item_product_price&#39;, &#39;double&#39;),
#  (&#39;order_item_quantity&#39;, &#39;bigint&#39;),
#  (&#39;order_item_subtotal&#39;, &#39;double&#39;)]</div>

# %%
import getpass
username = getpass.getuser()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.fs.ls(f'/user/{username}/retail_db_parquet/orders')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: [FileInfo(path=&#39;dbfs:/user/root/retail_db_parquet/orders/_committed_2813264261469267571&#39;, name=&#39;_committed_2813264261469267571&#39;, size=223),
#  FileInfo(path=&#39;dbfs:/user/root/retail_db_parquet/orders/_committed_3739854076266658903&#39;, name=&#39;_committed_3739854076266658903&#39;, size=123),
#  FileInfo(path=&#39;dbfs:/user/root/retail_db_parquet/orders/_committed_7198418882314090348&#39;, name=&#39;_committed_7198418882314090348&#39;, size=232),
#  FileInfo(path=&#39;dbfs:/user/root/retail_db_parquet/orders/_committed_7958689718562853532&#39;, name=&#39;_committed_7958689718562853532&#39;, size=222),
#  FileInfo(path=&#39;dbfs:/user/root/retail_db_parquet/orders/_committed_vacuum4032435399200819253&#39;, name=&#39;_committed_vacuum4032435399200819253&#39;, size=96),
#  FileInfo(path=&#39;dbfs:/user/root/retail_db_parquet/orders/_started_2813264261469267571&#39;, name=&#39;_started_2813264261469267571&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/retail_db_parquet/orders/_started_7958689718562853532&#39;, name=&#39;_started_7958689718562853532&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/retail_db_parquet/orders/part-00000-tid-2813264261469267571-eecb8f31-4c90-4763-89c5-6e2d7f0fafb1-168-1-c000.snappy.parquet&#39;, name=&#39;part-00000-tid-2813264261469267571-eecb8f31-4c90-4763-89c5-6e2d7f0fafb1-168-1-c000.snappy.parquet&#39;, size=489203)]</div>

# %%
df_parquet = spark.read.parquet(f'/user/{username}/retail_db_parquet/orders')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_parquet.inputFiles()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: [&#39;dbfs:/user/root/retail_db_parquet/orders/part-00000-tid-2813264261469267571-eecb8f31-4c90-4763-89c5-6e2d7f0fafb1-168-1-c000.snappy.parquet&#39;]</div>

# %%
df_parquet.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+--------------------+--------+---------------+
# order_customer_id|          order_date|order_id|   order_status|
# +-----------------+--------------------+--------+---------------+
#             11599|2013-07-25 00:00:...|       1|         CLOSED|
#               256|2013-07-25 00:00:...|       2|PENDING_PAYMENT|
#             12111|2013-07-25 00:00:...|       3|       COMPLETE|
#              8827|2013-07-25 00:00:...|       4|         CLOSED|
#             11318|2013-07-25 00:00:...|       5|       COMPLETE|
#              7130|2013-07-25 00:00:...|       6|       COMPLETE|
#              4530|2013-07-25 00:00:...|       7|       COMPLETE|
#              2911|2013-07-25 00:00:...|       8|     PROCESSING|
#              5657|2013-07-25 00:00:...|       9|PENDING_PAYMENT|
#              5648|2013-07-25 00:00:...|      10|PENDING_PAYMENT|
#               918|2013-07-25 00:00:...|      11| PAYMENT_REVIEW|
#              1837|2013-07-25 00:00:...|      12|         CLOSED|
#              9149|2013-07-25 00:00:...|      13|PENDING_PAYMENT|
#              9842|2013-07-25 00:00:...|      14|     PROCESSING|
#              2568|2013-07-25 00:00:...|      15|       COMPLETE|
#              7276|2013-07-25 00:00:...|      16|PENDING_PAYMENT|
#              2667|2013-07-25 00:00:...|      17|       COMPLETE|
#              1205|2013-07-25 00:00:...|      18|         CLOSED|
#              9488|2013-07-25 00:00:...|      19|PENDING_PAYMENT|
#              9198|2013-07-25 00:00:...|      20|     PROCESSING|
# +-----------------+--------------------+--------+---------------+
# only showing top 20 rows
#
# </div>

# %%
dbutils.fs.ls(f'/user/{username}/retail_db_pipe/orders')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[18]: [FileInfo(path=&#39;dbfs:/user/root/retail_db_pipe/orders/_committed_1132925174692068341&#39;, name=&#39;_committed_1132925174692068341&#39;, size=205),
#  FileInfo(path=&#39;dbfs:/user/root/retail_db_pipe/orders/_committed_1234588906270869920&#39;, name=&#39;_committed_1234588906270869920&#39;, size=202),
#  FileInfo(path=&#39;dbfs:/user/root/retail_db_pipe/orders/_committed_3648176934209418439&#39;, name=&#39;_committed_3648176934209418439&#39;, size=203),
#  FileInfo(path=&#39;dbfs:/user/root/retail_db_pipe/orders/_committed_3739906471235457527&#39;, name=&#39;_committed_3739906471235457527&#39;, size=200),
#  FileInfo(path=&#39;dbfs:/user/root/retail_db_pipe/orders/_committed_4737620600354584991&#39;, name=&#39;_committed_4737620600354584991&#39;, size=201),
#  FileInfo(path=&#39;dbfs:/user/root/retail_db_pipe/orders/_committed_4947663999967497501&#39;, name=&#39;_committed_4947663999967497501&#39;, size=202),
#  FileInfo(path=&#39;dbfs:/user/root/retail_db_pipe/orders/_committed_6648225221865780240&#39;, name=&#39;_committed_6648225221865780240&#39;, size=211),
#  FileInfo(path=&#39;dbfs:/user/root/retail_db_pipe/orders/_committed_8357199947666107777&#39;, name=&#39;_committed_8357199947666107777&#39;, size=201),
#  FileInfo(path=&#39;dbfs:/user/root/retail_db_pipe/orders/_committed_8757027839909558345&#39;, name=&#39;_committed_8757027839909558345&#39;, size=202),
#  FileInfo(path=&#39;dbfs:/user/root/retail_db_pipe/orders/_started_3648176934209418439&#39;, name=&#39;_started_3648176934209418439&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/retail_db_pipe/orders/part-00000-tid-3648176934209418439-0793934d-d4b2-4dbb-a518-7ed299cdcded-100-1-c000.csv&#39;, name=&#39;part-00000-tid-3648176934209418439-0793934d-d4b2-4dbb-a518-7ed299cdcded-100-1-c000.csv&#39;, size=2999944)]</div>

# %%
spark.read.csv(f'/user/{username}/retail_db_pipe/orders', sep='|')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[19]: DataFrame[_c0: string, _c1: string, _c2: string, _c3: string]</div>
