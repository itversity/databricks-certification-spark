# %%
# %fs ls dbfs:/databricks-datasets
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/databricks-datasets/COVID/</td><td>COVID/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/README.md</td><td>README.md</td><td>976</td></tr><tr><td>dbfs:/databricks-datasets/Rdatasets/</td><td>Rdatasets/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/SPARK_README.md</td><td>SPARK_README.md</td><td>3359</td></tr><tr><td>dbfs:/databricks-datasets/adult/</td><td>adult/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/airlines/</td><td>airlines/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/amazon/</td><td>amazon/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/asa/</td><td>asa/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/atlas_higgs/</td><td>atlas_higgs/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/bikeSharing/</td><td>bikeSharing/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/cctvVideos/</td><td>cctvVideos/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/credit-card-fraud/</td><td>credit-card-fraud/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/cs100/</td><td>cs100/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/cs110x/</td><td>cs110x/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/cs190/</td><td>cs190/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/data.gov/</td><td>data.gov/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/definitive-guide/</td><td>definitive-guide/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/delta-sharing/</td><td>delta-sharing/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/flights/</td><td>flights/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/flower_photos/</td><td>flower_photos/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/flowers/</td><td>flowers/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/genomics/</td><td>genomics/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/hail/</td><td>hail/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/iot/</td><td>iot/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/iot-stream/</td><td>iot-stream/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/learning-spark/</td><td>learning-spark/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/learning-spark-v2/</td><td>learning-spark-v2/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/lending-club-loan-stats/</td><td>lending-club-loan-stats/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/med-images/</td><td>med-images/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/mnist-digits/</td><td>mnist-digits/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/news20.binary/</td><td>news20.binary/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi/</td><td>nyctaxi/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi-with-zipcodes/</td><td>nyctaxi-with-zipcodes/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/online_retail/</td><td>online_retail/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/overlap-join/</td><td>overlap-join/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/power-plant/</td><td>power-plant/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/retail-org/</td><td>retail-org/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/rwe/</td><td>rwe/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/sai-summit-2019-sf/</td><td>sai-summit-2019-sf/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/</td><td>sample_logs/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/samples/</td><td>samples/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/sfo_customer_survey/</td><td>sfo_customer_survey/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/sms_spam_collection/</td><td>sms_spam_collection/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/songs/</td><td>songs/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/structured-st ...

# %%
# %fs ls dbfs:/databricks-datasets/asa/airlines
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/databricks-datasets/asa/airlines/1987.csv</td><td>1987.csv</td><td>127162942</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/1988.csv</td><td>1988.csv</td><td>501039472</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/1989.csv</td><td>1989.csv</td><td>486518821</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/1990.csv</td><td>1990.csv</td><td>509194687</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/1991.csv</td><td>1991.csv</td><td>491210093</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/1992.csv</td><td>1992.csv</td><td>492313731</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/1993.csv</td><td>1993.csv</td><td>490753652</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/1994.csv</td><td>1994.csv</td><td>501558665</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/1995.csv</td><td>1995.csv</td><td>530751568</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/1996.csv</td><td>1996.csv</td><td>533922363</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/1997.csv</td><td>1997.csv</td><td>540347861</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/1998.csv</td><td>1998.csv</td><td>538432875</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/1999.csv</td><td>1999.csv</td><td>552926022</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/2000.csv</td><td>2000.csv</td><td>570151613</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/2001.csv</td><td>2001.csv</td><td>600411462</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/2002.csv</td><td>2002.csv</td><td>530507013</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/2003.csv</td><td>2003.csv</td><td>626745242</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/2004.csv</td><td>2004.csv</td><td>669879113</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/2005.csv</td><td>2005.csv</td><td>671027265</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/2006.csv</td><td>2006.csv</td><td>672068096</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/2007.csv</td><td>2007.csv</td><td>702878193</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/2008.csv</td><td>2008.csv</td><td>689413344</td></tr></tbody></table></div>

# %%
import getpass
username = getpass.getuser()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.fs.rm(f'/user/{username}/asa/airlines', recurse=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[31]: True</div>

# %%
spark.read.csv('dbfs:/databricks-datasets/asa/airlines', header=True). \
    write. \
    partitionBy('Year'). \
    csv(f'/user/{username}/asa/airlines', header=True, mode='overwrite')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.fs.ls(f'/user/{username}/asa/airlines/')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: [FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=1987/&#39;, name=&#39;Year=1987/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=1988/&#39;, name=&#39;Year=1988/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=1989/&#39;, name=&#39;Year=1989/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=1990/&#39;, name=&#39;Year=1990/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=1991/&#39;, name=&#39;Year=1991/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=1992/&#39;, name=&#39;Year=1992/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=1993/&#39;, name=&#39;Year=1993/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=1994/&#39;, name=&#39;Year=1994/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=1995/&#39;, name=&#39;Year=1995/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=1996/&#39;, name=&#39;Year=1996/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=1997/&#39;, name=&#39;Year=1997/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=1998/&#39;, name=&#39;Year=1998/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=1999/&#39;, name=&#39;Year=1999/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=2000/&#39;, name=&#39;Year=2000/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=2001/&#39;, name=&#39;Year=2001/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=2002/&#39;, name=&#39;Year=2002/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=2003/&#39;, name=&#39;Year=2003/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=2004/&#39;, name=&#39;Year=2004/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=2005/&#39;, name=&#39;Year=2005/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=2006/&#39;, name=&#39;Year=2006/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=2007/&#39;, name=&#39;Year=2007/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=2008/&#39;, name=&#39;Year=2008/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/_SUCCESS&#39;, name=&#39;_SUCCESS&#39;, size=0)]</div>

# %%
spark.read.csv(f'/user/{username}/asa/airlines/', header=True).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: 123534969</div>

# %%
dbutils.fs.ls(f'/user/{username}/asa/airlines/Year=2004')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: [FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=2004/_SUCCESS&#39;, name=&#39;_SUCCESS&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=2004/_committed_5354510644224401868&#39;, name=&#39;_committed_5354510644224401868&#39;, size=474),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=2004/_started_5354510644224401868&#39;, name=&#39;_started_5354510644224401868&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=2004/part-00054-tid-5354510644224401868-b9d65333-9c57-4344-9f60-9e5b29601d04-1144-1.c000.csv&#39;, name=&#39;part-00054-tid-5354510644224401868-b9d65333-9c57-4344-9f60-9e5b29601d04-1144-1.c000.csv&#39;, size=129852177),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=2004/part-00055-tid-5354510644224401868-b9d65333-9c57-4344-9f60-9e5b29601d04-1145-1.c000.csv&#39;, name=&#39;part-00055-tid-5354510644224401868-b9d65333-9c57-4344-9f60-9e5b29601d04-1145-1.c000.csv&#39;, size=129893495),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=2004/part-00056-tid-5354510644224401868-b9d65333-9c57-4344-9f60-9e5b29601d04-1146-1.c000.csv&#39;, name=&#39;part-00056-tid-5354510644224401868-b9d65333-9c57-4344-9f60-9e5b29601d04-1146-1.c000.csv&#39;, size=129873907),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=2004/part-00057-tid-5354510644224401868-b9d65333-9c57-4344-9f60-9e5b29601d04-1147-1.c000.csv&#39;, name=&#39;part-00057-tid-5354510644224401868-b9d65333-9c57-4344-9f60-9e5b29601d04-1147-1.c000.csv&#39;, size=129870679),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=2004/part-00078-tid-5354510644224401868-b9d65333-9c57-4344-9f60-9e5b29601d04-1168-1.c000.csv&#39;, name=&#39;part-00078-tid-5354510644224401868-b9d65333-9c57-4344-9f60-9e5b29601d04-1168-1.c000.csv&#39;, size=128746946)]</div>
