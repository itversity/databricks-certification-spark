# %%
import getpass
username = getpass.getuser()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark.read.csv('dbfs:/databricks-datasets/asa/airlines', header=True).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: 123534969</div>

# %%
spark.read.csv(f'/user/{username}/asa/airlines', header=True).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: 123534969</div>

# %%
spark.read.csv('dbfs:/databricks-datasets/asa/airlines', header=True). \
    filter('Year = 2004'). \
    count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: 7129270</div>

# %%
spark.read.csv(f'/user/{username}/asa/airlines/Year=2004', header=True).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: 7129270</div>

# %%
dbutils.fs.ls(f'/user/{username}/asa/airlines/')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: [FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=1987/&#39;, name=&#39;Year=1987/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=1988/&#39;, name=&#39;Year=1988/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=1989/&#39;, name=&#39;Year=1989/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=1990/&#39;, name=&#39;Year=1990/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=1991/&#39;, name=&#39;Year=1991/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=1992/&#39;, name=&#39;Year=1992/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=1993/&#39;, name=&#39;Year=1993/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=1994/&#39;, name=&#39;Year=1994/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=1995/&#39;, name=&#39;Year=1995/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=1996/&#39;, name=&#39;Year=1996/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=1997/&#39;, name=&#39;Year=1997/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=1998/&#39;, name=&#39;Year=1998/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=1999/&#39;, name=&#39;Year=1999/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=2000/&#39;, name=&#39;Year=2000/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=2001/&#39;, name=&#39;Year=2001/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=2002/&#39;, name=&#39;Year=2002/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=2003/&#39;, name=&#39;Year=2003/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=2004/&#39;, name=&#39;Year=2004/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=2005/&#39;, name=&#39;Year=2005/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=2006/&#39;, name=&#39;Year=2006/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=2007/&#39;, name=&#39;Year=2007/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/Year=2008/&#39;, name=&#39;Year=2008/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/root/asa/airlines/_SUCCESS&#39;, name=&#39;_SUCCESS&#39;, size=0)]</div>

# %%
spark.read.csv(f'/user/{username}/asa/airlines', header=True).filter('Year = 2004').count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: 7129270</div>

# %%
airlines_df = spark.read.csv(f'/user/{username}/asa/airlines', header=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
airlines_df. \
    createOrReplaceTempView('airlines')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark.sql('SHOW tables').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+---------+-----------+
# database|tableName|isTemporary|
# +--------+---------+-----------+
#         | airlines|       true|
# +--------+---------+-----------+
#
# </div>

# %%
spark.sql('''
    SELECT count(*)
    FROM airlines
    WHERE year = 2004
''').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+
# count(1)|
# +--------+
#  7129270|
# +--------+
#
# </div>
